# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd # data data processing
import numpy as np #linear algebra

#import data
data=pd.read_csv("./database/star_classification.csv")

# %%
data
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 0      1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1      1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2      1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3      1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4      1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# ...

# %%
#check info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   obj_ID       100000 non-null  float64
#  1   alpha        100000 non-null  float64
#  2   delta        100000 non-null  float64
#  3   u            100000 non-null  float64
#  4   g            100000 non-null  float64
#  5   r            100000 non-null  float64
#  6   i            100000 non-null  float64
#  7   z            100000 non-null  float64
#  8   run_ID       100000 non-null  int64
#  9   rerun_ID     100000 non-null  int64
#  10  cam_col      100000 non-null  int64
#  11  field_ID     100000 non-null  int64
#  12  spec_obj_ID  100000 non-null  float64
#  13  class        100000 non-null  object
#  14  redshift     100000 non-null  float64
#  15  plate        100000 non-null  int64
#  16  MJD          100000 non-null  int64
#  17  fiber_ID     100000 non-null  int64
# ...

# %%
# handle none numaric data
# GALAXY= 0, STAR=1, QSO=2.
data["class"]=[0 if i == "GALAXY" else 1 if i == "STAR" else 2 for i in data["class"]]

# %%
#visiualisation on row data
import matplotlib.pyplot as plt
class_counts= data["class"].value_counts()

#creating a chart
plt.figure(figsize= (4,2.5))
plt.bar(class_counts.index, class_counts.values, color='skyblue')
plt.title('Distribution of Stellar Classes in Raw Data', fontsize=13)
plt.xlabel('Stellar Class', fontsize=11)
plt.ylabel('Count', fontsize=11)
plt.xticks(ticks=[0, 1, 2], labels=['GALAXY', 'STAR', 'QSO'], fontsize=9)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Show the plot
plt.show()

# %%
data.describe()
# Out:
#              obj_ID          alpha          delta              u  \
# count  1.000000e+05  100000.000000  100000.000000  100000.000000
# mean   1.237665e+18     177.629117      24.135305      21.980468
# std    8.438560e+12      96.502241      19.644665      31.769291
# min    1.237646e+18       0.005528     -18.785328   -9999.000000
# 25%    1.237659e+18     127.518222       5.146771      20.352353
# 50%    1.237663e+18     180.900700      23.645922      22.179135
# 75%    1.237668e+18     233.895005      39.901550      23.687440
# max    1.237681e+18     359.999810      83.000519      32.781390
#
#                    g              r              i              z  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       20.531387      19.645762      19.084854      18.668810
# std        31.750292       1.854760       1.757895      31.728152
# min     -9999.000000       9.822070       9.469903   -9999.000000
# ...

# %%
from sklearn.neighbors import LocalOutlierFactor
clf = LocalOutlierFactor()
y_pred = clf.fit_predict(data) 
x_score = clf.negative_outlier_factor_
outlier_score = pd.DataFrame()
outlier_score["score"] = x_score

#threshold
threshold2 = -1.5                                            
filtre2 = outlier_score["score"] < threshold2
outlier_index = outlier_score[filtre2].index.tolist()
# Out:
# C:\Anakonda\Lib\site-packages\joblib\externals\loky\backend\context.py:110: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Anakonda\Lib\site-packages\joblib\externals\loky\backend\context.py", line 217, in _count_physical_cores
#     raise ValueError(

# %%
print(len(outlier_index))
# Out:
# 15256

# %%
data.drop(outlier_index, inplace=True)

# %%
#feature selection 
import seaborn as sns
f,ax = plt.subplots(figsize=(12,8))
sns.heatmap(data.corr(), cmap="PuBu", annot=True, linewidths=0.5, fmt= '.2f',ax=ax)
plt.show()

# %%
corr = data.corr()
corr["class"].sort_values()
# Out:
# u             -0.222802
# g             -0.058192
# field_ID      -0.037542
# run_ID         0.000250
# obj_ID         0.000252
# alpha          0.008187
# cam_col        0.017789
# fiber_ID       0.037319
# delta          0.058947
# r              0.160654
# MJD            0.214433
# spec_obj_ID    0.224718
# plate          0.224718
# i              0.294075
# z              0.349711
# redshift       0.541667
# class          1.000000
# rerun_ID            NaN
# Name: class, dtype: float64

# %%
print(data.columns)
# Out:
# Index(['obj_ID', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'run_ID',
#        'rerun_ID', 'cam_col', 'field_ID', 'spec_obj_ID', 'class', 'redshift',
#        'plate', 'MJD', 'fiber_ID'],
#       dtype='object')

# %%
data = data.drop(['obj_ID','alpha','delta','run_ID','rerun_ID','cam_col','field_ID','fiber_ID'], axis = 1)

# %%
print(data.columns)
# Out:
# Index(['u', 'g', 'r', 'i', 'z', 'spec_obj_ID', 'class', 'redshift', 'plate',
#        'MJD'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
x = data.drop(['class'], axis = 1)
y = data.loc[:,'class'].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.4, random_state = 42)
data
# Out:
#               u         g         r         i         z   spec_obj_ID  class  \
# 0      23.87882  22.27530  20.39501  19.16573  18.79371  6.543777e+18      0
# 1      24.77759  22.83188  22.58444  21.16812  21.61427  1.176014e+19      0
# 3      22.13682  23.77656  21.61162  20.50454  19.25010  1.030107e+19      0
# 4      19.43718  17.58028  16.49747  15.97711  15.54461  6.891865e+18      0
# 6      21.46973  21.17624  20.92829  20.60826  20.42573  1.246262e+19      2
# ...         ...       ...       ...       ...       ...           ...    ...
# 99994  20.96526  19.81625  19.34186  19.14711  19.05790  1.154061e+18      0
# 99995  22.16759  22.97586  21.90404  21.30548  20.73569  1.055431e+19      0
# 99996  22.69118  22.38628  20.45003  19.75759  19.41526  8.586351e+18      0
# 99997  21.16916  19.26997  18.20428  17.69034  17.35221  3.112008e+18      0
# 99999  22.62171  21.79745  20.60115  20.00959  19.28075  8.343152e+18      0
#
#        redshift  plate    MJD
# ...

# %%
#reducing training size for effeciency
x_train= x_train[:500]
y_train= y_train[:500]

# %%
print(x_train.shape)
# Out:
# (500, 9)

# %%
print(y_train.shape)
# Out:
# (500,)

# %%
#Dealing with Imbalanced Data
from imblearn.over_sampling import SMOTE
from collections import Counter

x = data.drop(['class'], axis = 1)
y = data.loc[:,'class'].values


sm = SMOTE(random_state=42)
print('Original dataset shape %s' % Counter(y))
x, y = sm.fit_resample(x, y)
print('Resampled dataset shape %s' % Counter(y))
# Out:
# Original dataset shape Counter({0: 50695, 1: 17890, 2: 16159})
# Resampled dataset shape Counter({0: 50695, 2: 50695, 1: 50695})

# %%
sns.countplot(x=y, palette='Set3')
plt.title("Class Distribution", fontsize=10)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
x = scaler.transform(x)

# %% [markdown]
# # Data Training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

logreg = LogisticRegression()
svm = SVC(probability=True)
mlp = MLPClassifier(random_state=42, max_iter=500)

# %%
# Fitting Logistic Regression model
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#Fitting Support Vector Machine model
svm.fit(x_train, y_train)
# Out:
# SVC(probability=True)

# %%
#Fitting Multi-Layer Perceptron model
mlp.fit(x_train, y_train)
# Out:
# MLPClassifier(max_iter=500, random_state=42)

# %%
#Support Vector Machine training model
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV 

svm_param_grid= {
    "C": [0.1, 1, 10],
    "kernel": ["linear", "rbf"],
    "gamma": ["scale", "auto"]
}
svm= SVC(probability=True)
svm_grid_search= GridSearchCV(svm, svm_param_grid, cv=3, scoring="f1", verbose=1)
svm_grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %%
#Logistic Regression training model
from sklearn.linear_model import LogisticRegression

lr_param_grid= {
    "C": [0.1, 1, 10],
    "penalty": ["l1", "l2", "elasticnet", "none"],
    "solver": ["liblinear", "saga"]
}
logreg= LogisticRegression(max_iter=500)
lr_grid_search= GridSearchCV(logreg, lr_param_grid, cv=5, scoring="f1", verbose=1)
lr_grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anakonda\Lib\site-packages\sklearn\model_selection\_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Anakonda\Lib\site-packages\sklearn\model_selection\_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Anakonda\Lib\site-packages\sklearn\metrics\_scorer.py", line 288, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Anakonda\Lib\site-packages\sklearn\metrics\_scorer.py", line 388, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
# ...

# %%
#Multi-Layer Perceptron training model
mlp_params= {
    "hidden_layer_sizes": [(50,), (100,), (100,50)],
    "activation": ["relu", "tanh"],
    "solver": ["adam", "sgd"],
    "alpha": [0.0001, 0.001, 0.01]
}
mlp_grid_search= GridSearchCV(mlp, mlp_params, scoring="accuracy", cv=3)
mlp_grid_search.fit(x_train, y_train)
# Out:
# C:\Anakonda\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Anakonda\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Anakonda\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Anakonda\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
best_svm= svm_grid_search.best_estimator_
best_svm
# Out:
# SVC(C=0.1, kernel='linear', probability=True)

# %%
best_lr= lr_grid_search.best_estimator_
best_lr
# Out:
# LogisticRegression(C=0.1, max_iter=500, penalty='l1', solver='liblinear')

# %%
best_mlp=mlp_grid_search.best_estimator_
best_mlp
# Out:
# MLPClassifier(activation='tanh', hidden_layer_sizes=(100, 50), max_iter=500,
#               random_state=42)

# %% [markdown]
# # Model evaluation

# %%
y_pred_logreg=logreg.predict(x_test)
print(f"Logistic Regression Predictions: {y_pred_logreg[:10]}")
# Out:
# Logistic Regression Predictions: [0 1 2 2 0 1 1 0 2 2]

# %%
y_pred_svm = svm.predict(x_test)
print(f"SVM Predictions: {y_pred_svm[:10]}")
# Out:
# SVM Predictions: [0 1 2 2 0 1 1 0 2 2]

# %%
y_pred_mlp= mlp.predict(x_test)
print(f"MLP Prediction: {y_pred_mlp[:10]}")
# Out:
# MLP Prediction: [0 1 2 2 0 1 1 0 2 2]

# %%
models= {"MLP": best_mlp, "SVM": best_svm, "Logistic Regression": best_lr}
for model_name, model in models.items():
    print(f"Evaluating {model_name}...")
    y_pred= model.predict(x_test)
    y_pred_proba= model.predict_proba(x_test)[:,1]
# Out:
# Evaluating MLP...
# Evaluating SVM...
# Evaluating Logistic Regression...

# %%
print(y_pred_proba.shape)
# Out:
# (50189,)

# %%
y_pred_proba_svm=svm.predict_proba(x_test)
print(y_pred_proba_svm.shape)
# Out:
# (50189, 3)

# %%
y_pred_proba_logreg=logreg.predict_proba(x_test)
print(y_pred_proba_logreg.shape)
# Out:
# (50189, 3)

# %%
y_pred_proba_mlp= mlp.predict_proba(x_test)
print(y_pred_proba_mlp.shape)
# Out:
# (50189, 3)

# %%
#Logistic Regression metrics
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred_logreg, average="weighted")
recall = recall_score(y_test, y_pred_logreg, average="weighted")
f1 = f1_score(y_test, y_pred_logreg, average="weighted")
auc_roc = roc_auc_score(y_test, y_pred_proba_logreg, multi_class="ovr")

model_name = "Logistic Regression"
print(f"\n{model_name} Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"AUC-ROC: {auc_roc:.4f}")
# Out:
# Logistic Regression Metrics:
# Accuracy: 0.8314
# Precision: 0.9165
# Recall: 0.9153
# F1-Score: 0.9147
# AUC-ROC: 0.9826

# %%
#Support Vector Machine metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred_svm, average="weighted")
recall = recall_score(y_test, y_pred_svm, average="weighted")
f1 = f1_score(y_test, y_pred_svm, average="weighted")
auc_roc = roc_auc_score(y_test, y_pred_proba_svm, multi_class="ovr")

model_name = "Support Vector Machine"
print(f"\n{model_name} Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"AUC-ROC: {auc_roc:.4f}")
# Out:
# Support Vector Machine Metrics:
# Accuracy: 0.8314
# Precision: 0.9052
# Recall: 0.9023
# F1-Score: 0.9026
# AUC-ROC: 0.9777

# %%
#Multi-Layer Perceptron metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred_mlp, average="weighted")
recall = recall_score(y_test, y_pred_mlp, average="weighted")
f1 = f1_score(y_test, y_pred_mlp, average="weighted")
auc_roc = roc_auc_score(y_test, y_pred_proba_mlp, multi_class="ovr")

model_name = "Multi-Layer Perceptron"
print(f"\n{model_name} Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"AUC-ROC: {auc_roc:.4f}")
# Out:
# Multi-Layer Perceptron Metrics:
# Accuracy: 0.8314
# Precision: 0.9492
# Recall: 0.9491
# F1-Score: 0.9490
# AUC-ROC: 0.9897

# %%
#Confusion Matrix for logistic regression
conf_matrix= confusion_matrix(y_test, y_pred_logreg)
disp=ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=np.unique(y))
disp.plot(cmap=plt.cm.Blues)
plt.title(f"Confusion Matrix for {logreg}")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Confusion Matrix for Multi-Layer Perceptron
conf_matrix= confusion_matrix(y_test, y_pred_svm)
disp=ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=np.unique(y))
disp.plot(cmap=plt.cm.Blues)
plt.title(f"Confusion Matrix for {svm}")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Confusion Matrix for Multi-Layer Perceptron
conf_matrix= confusion_matrix(y_test, y_pred_mlp)
disp=ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=np.unique(y))
disp.plot(cmap=plt.cm.Blues)
plt.title(f"Confusion Matrix for {mlp}")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Hyperparameter tuning results
print("Best parameters for Support Vector Machine:", svm_grid_search.best_params_)
print("Best parameters for Logistic Regression:", lr_grid_search.best_params_)
print("Best parameters for Multi-Layer Perceptron:", mlp_grid_search.best_params_)
# Out:
# Best parameters for Support Vector Machine: {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# Best parameters for Logistic Regression: {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
# Best parameters for Multi-Layer Perceptron: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'solver': 'adam'}
